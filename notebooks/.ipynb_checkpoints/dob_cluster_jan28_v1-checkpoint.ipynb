# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import sklearn.cluster as cluster
from matplotlib.pylab import plt
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist, pdist
import zipfile
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
features = pd.read_csv('../data_processed/all_features')

# %%
features.head()
# Out:
#    Unnamed: 0  ZIPCODE  complaints  unemployment  poor_english  \
# 0           0  11208.0       642.0          10.2          16.9
# 1           1  11419.0       617.0          10.2          14.8
# 2           2  11420.0       438.0          11.0          11.3
# 3           3  11355.0       355.0           7.2          65.8
# 4           4  11220.0       331.0           9.5          56.3
#
#    household_income  violations  comp_vio_ratio  POPULATION  disability_r  \
# 0           35698.0        19.1       33.617801     94410.0         0.084
# 1           58266.0        22.1       27.923077     47054.0         0.076
# 2           59660.0        19.1       22.937173     44538.0         0.096
# 3           39168.0        25.1       14.147410     82809.0         0.069
# 4           38893.0         9.1       36.384615     97257.0         0.080
#
#         ...         below_poverty_r  male_pop_r  female_pop_r  elder_pop_r  \
# 0       ...                   0.304    0.464682      0.535318     0.000083
# 1       ...                   0.172    0.499716      0.500284     0.000187
# 2       ...                   0.131    0.474892      0.525108     0.000211
# 3       ...                   0.215    0.479961      0.520039     0.000182
# 4       ...                   0.330    0.511840      0.488160     0.000088
#
#     white_r   black_r   asian_r  native_r  towork_less30_r  towork_over30_r
# 0  0.266093  0.543214  0.054354  0.003793         0.144436         0.855564
# 1  0.110392  0.184562  0.292094  0.009350         0.219422         0.780578
# 2  0.161118  0.257517  0.232999  0.016568         0.255918         0.744082
# 3  0.138797  0.028494  0.733180  0.006474         0.294329         0.705671
# 4  0.267989  0.023758  0.412118  0.007193         0.260417         0.739583
#
# [5 rows x 36 columns]

# %%
features.columns
# Out:
# Index([u'Unnamed: 0', u'ZIPCODE', u'complaints', u'unemployment',
#        u'poor_english', u'household_income', u'violations', u'comp_vio_ratio',
#        u'POPULATION', u'disability_r', u'edu_high_r', u'edu_low_r',
#        u'employment_r', u'hh', u'hh_with6_r', u'utility_gas_r', u'tank_gas_r',
#        u'electricity_r', u'fueloil_r', u'coal_r', u'other_fuels_r',
#        u'occupied_hu_own_r', u'occupied_hu_rent_r', u'built_before1980_r',
#        u'married_r', u'non_eng_r', u'below_poverty_r', u'male_pop_r',
#        u'female_pop_r', u'elder_pop_r', u'white_r', u'black_r', u'asian_r',
#        u'native_r', u'towork_less30_r', u'towork_over30_r'],
#       dtype='object')

# %%
features = features.drop('Unnamed: 0', axis=1)

# %%
#features.isnull().sum()

# %%
#features = features.drop('pop', axis=1)
#features = features.drop(['non_eng_r', 'occupied_hu_rent_r', 'towork_over30_r', 'utility_gas_r', 'tank_gas_r', 'electricity_r', 'fueloil_r', 'coal_r', 'other_fuels_r', 'male_pop_r', 'employment_r', 'POPULATION'], axis=1)

# %%
features = features.set_index('ZIPCODE')

# %%
print(len(features))
# Out:
# 174

# %%
features.head(10)
# Out:
#          complaints  unemployment  poor_english  household_income  violations  \
# ZIPCODE
# 11208.0       642.0          10.2          16.9           35698.0        19.1
# 11419.0       617.0          10.2          14.8           58266.0        22.1
# 11420.0       438.0          11.0          11.3           59660.0        19.1
# 11355.0       355.0           7.2          65.8           39168.0        25.1
# 11220.0       331.0           9.5          56.3           38893.0         9.1
# 11207.0       321.0          13.2          12.9           34252.0        10.1
# 11385.0       317.0           7.2          24.6           55331.0        23.1
# 11373.0       267.0           6.1          55.2           47588.0        23.1
# 11432.0       263.0          10.4          34.8           50702.0        14.1
# 11228.0       258.0           8.8          29.4           64250.0        16.1
#
#          comp_vio_ratio  POPULATION  disability_r  edu_high_r  edu_low_r  \
# ZIPCODE
# 11208.0       33.617801     94410.0         0.084       0.132      0.456
# 11419.0       27.923077     47054.0         0.076       0.178      0.363
# 11420.0       22.937173     44538.0         0.096       0.176      0.328
# 11355.0       14.147410     82809.0         0.069       0.238      0.280
# 11220.0       36.384615     97257.0         0.080       0.182      0.211
# 11207.0       31.792079     93556.0         0.119       0.136      0.348
# 11385.0       13.727273     98436.0         0.062       0.222      0.345
# 11373.0       11.562771    101282.0         0.083       0.270      0.251
# 11432.0       18.659574     62075.0         0.082       0.347      0.220
# 11228.0       16.031056     43080.0         0.097       0.314      0.282
#
#               ...         below_poverty_r  male_pop_r  female_pop_r  \
# ZIPCODE       ...
# 11208.0       ...                   0.304    0.464682      0.535318
# 11419.0       ...                   0.172    0.499716      0.500284
# 11420.0       ...                   0.131    0.474892      0.525108
# 11355.0       ...                   0.215    0.479961      0.520039
# 11220.0       ...                   0.330    0.511840      0.488160
# 11207.0       ...                   0.317    0.448398      0.551602
# 11385.0       ...                   0.156    0.490681      0.509319
# 11373.0       ...                   0.206    0.509589      0.490411
# 11432.0       ...                   0.199    0.475092      0.524908
# 11228.0       ...                   0.127    0.485442      0.514558
#
#          elder_pop_r   white_r   black_r   asian_r  native_r  towork_less30_r  \
# ZIPCODE
# 11208.0     0.000083  0.266093  0.543214  0.054354  0.003793         0.144436
# 11419.0     0.000187  0.110392  0.184562  0.292094  0.009350         0.219422
# 11420.0     0.000211  0.161118  0.257517  0.232999  0.016568         0.255918
# 11355.0     0.000182  0.138797  0.028494  0.733180  0.006474         0.294329
# 11220.0     0.000088  0.267989  0.023758  0.412118  0.007193         0.260417
# 11207.0     0.000100  0.130482  0.651172  0.013269  0.005293         0.205857
# 11385.0     0.000100  0.828264  0.021319  0.066961  0.003101         0.177580
# 11373.0     0.000121  0.341295  0.018477  0.494358  0.005114         0.210831
# 11432.0     0.000205  0.225804  0.154880  0.417925  0.005808         0.255214
# 11228.0     0.000331  0.610871  0.012376  0.324709  0.002776         0.290624
#
#          towork_over30_r
# ZIPCODE
# 11208.0         0.855564
# 11419.0         0.780578
# 11420.0         0.744082
# 11355.0         0.705671
# 11220.0         0.739583
# 11207.0         0.794143
# 11385.0         0.822420
# 11373.0         0.789169
# 11432.0         0.744786
# 11228.0         0.709376
#
# [10 rows x 34 columns]

# %%
features = features.apply(pd.to_numeric, errors='coerce')

# %%
#features.head()

# %%
features = features.dropna()

# %%
#standardize features in preparation for cluster analysis
features = features.T
features_stand = (features - features.mean()) / features.std()
features_stand = features_stand.T
features_stand.head(10)
# Out:
#          complaints  unemployment  poor_english  household_income  violations  \
# ZIPCODE
# 11208.0   -0.230904     -0.266636     -0.266257          1.751692   -0.266132
# 11419.0   -0.224987     -0.272644     -0.272283          4.302680   -0.271710
# 11420.0   -0.239403     -0.273053     -0.273029          4.427550   -0.272414
# 11355.0   -0.252718     -0.274414     -0.270759          2.168546   -0.273298
# 11220.0   -0.248998     -0.266587     -0.264027          1.860682   -0.266609
# 11207.0   -0.249817     -0.267329     -0.267346          1.680598   -0.267505
# 11385.0   -0.265060     -0.280717     -0.279837          2.515270   -0.279913
# 11373.0   -0.258714     -0.272094     -0.269576          2.168184   -0.271222
# 11432.0   -0.261844     -0.280195     -0.278422          3.402436   -0.279926
# 11228.0   -0.253901     -0.272742     -0.271185          4.584266   -0.272190
#
#          comp_vio_ratio  POPULATION  disability_r  edu_high_r  edu_low_r  \
# ZIPCODE
# 11208.0       -0.265311    5.072157     -0.267208   -0.267205  -0.267187
# 11419.0       -0.271252    3.422106     -0.273439   -0.273431  -0.273417
# 11420.0       -0.272112    3.235870     -0.273912   -0.273906  -0.273894
# 11355.0       -0.273981    4.890993     -0.274859   -0.274849  -0.274846
# 11220.0       -0.265116    5.053705     -0.267103   -0.267097  -0.267095
# 11207.0       -0.266271    5.054544     -0.268073   -0.268072  -0.268060
# 11385.0       -0.280387    4.693736     -0.281077   -0.281069  -0.281063
# 11373.0       -0.271814    4.921925     -0.272403   -0.272393  -0.272394
# 11432.0       -0.279595    4.228659     -0.280945   -0.280925  -0.280935
# 11228.0       -0.272196    2.983691     -0.273400   -0.273384  -0.273386
#
#               ...         below_poverty_r  male_pop_r  female_pop_r  \
# ZIPCODE       ...
# 11208.0       ...               -0.267195   -0.267186     -0.267182
# 11419.0       ...               -0.273432   -0.273406     -0.273406
# 11420.0       ...               -0.273909   -0.273882     -0.273878
# 11355.0       ...               -0.274850   -0.274834     -0.274831
# 11220.0       ...               -0.267089   -0.267079     -0.267080
# 11207.0       ...               -0.268062   -0.268054     -0.268048
# 11385.0       ...               -0.281073   -0.281056     -0.281055
# 11373.0       ...               -0.272396   -0.272381     -0.272382
# 11432.0       ...               -0.280936   -0.280916     -0.280912
# 11228.0       ...               -0.273398   -0.273371     -0.273369
#
#          elder_pop_r   white_r   black_r   asian_r  native_r  towork_less30_r  \
# ZIPCODE
# 11208.0    -0.267213 -0.267198 -0.267182 -0.267210 -0.267212        -0.267204
# 11419.0    -0.273445 -0.273437 -0.273431 -0.273422 -0.273444        -0.273428
# 11420.0    -0.273919 -0.273907 -0.273899 -0.273901 -0.273918        -0.273899
# 11355.0    -0.274863 -0.274855 -0.274862 -0.274818 -0.274863        -0.274845
# 11220.0    -0.267107 -0.267092 -0.267106 -0.267084 -0.267107        -0.267093
# 11207.0    -0.268080 -0.268072 -0.268043 -0.268079 -0.268079        -0.268068
# 11385.0    -0.281081 -0.281039 -0.281079 -0.281077 -0.281080        -0.281072
# 11373.0    -0.272407 -0.272389 -0.272406 -0.272382 -0.272407        -0.272396
# 11432.0    -0.280951 -0.280934 -0.280939 -0.280920 -0.280950        -0.280932
# 11228.0    -0.273408 -0.273362 -0.273407 -0.273383 -0.273408        -0.273386
#
#          towork_over30_r
# ZIPCODE
# 11208.0        -0.267164
# 11419.0        -0.273384
# 11420.0        -0.273861
# 11355.0        -0.274819
# 11220.0        -0.267066
# 11207.0        -0.268034
# 11385.0        -0.281039
# 11373.0        -0.272366
# 11432.0        -0.280896
# 11228.0        -0.273354
#
# [10 rows x 34 columns]

# %%
#features_stand.isnull().sum()

# %%
# determine number of clusters with sillhouette score
range_n_clusters = [2, 3, 4, 5, 6, 7, 8, 9]
for n_clusters in range_n_clusters:
    km = KMeans(n_clusters=n_clusters, random_state=324)
    cluster_labels = km.fit_predict(features_stand)
    silhouette_avg = silhouette_score(features_stand, cluster_labels)
    print("For n_clusters ={},".format(n_clusters)+" the average silhouette_score is :{}".format(silhouette_avg))
# Out:
# For n_clusters =2, the average silhouette_score is :0.634790287869
# For n_clusters =3, the average silhouette_score is :0.563105284349
# For n_clusters =4, the average silhouette_score is :0.537298625562
# For n_clusters =5, the average silhouette_score is :0.518400067026
# For n_clusters =6, the average silhouette_score is :0.507292915116
# For n_clusters =7, the average silhouette_score is :0.501078784443
# For n_clusters =8, the average silhouette_score is :0.475159236371
# For n_clusters =9, the average silhouette_score is :0.472698432992

# %%
def elbow(data,K):
#data is your input as numpy form
#K is a list of number of clusters you would like to show.
    # Run the KMeans model and save all the results for each number of clusters
    KM = [KMeans(n_clusters=k).fit(data) for k in K]
    
    # Save the centroids for each model with a increasing k
    centroids = [k.cluster_centers_ for k in KM]

    # For each k, get the distance between the data with each center. 
    D_k = [cdist(data, cent, 'euclidean') for cent in centroids]
    
    # But we only need the distance to the nearest centroid since we only calculate dist(x,ci) for its own cluster.
    globals()['dist'] = [np.min(D,axis=1) for D in D_k]
    
    # Calculate the Average SSE.
    avgWithinSS = [sum(d)/data.shape[0] for d in dist]
    
    
    # elbow curve
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(K, avgWithinSS, 'b*-')
    plt.grid(True)
    plt.xlabel('Number of clusters')
    plt.ylabel('Average within-cluster sum of squares')
    plt.title('Elbow for KMeans clustering')
    plt.show()

elbow(features, range(1,15))

# %%
n = 4
km = cluster.KMeans(n_clusters=n, random_state=324)
km.fit(features_stand)
features_stand_KM = km.predict(features_stand)
centers = km.cluster_centers_
labels = km.labels_

# %%
features_stand['cluster_label'] = labels

# %%
features_stand.head()
# Out:
#          complaints  unemployment  poor_english  household_income  violations  \
# ZIPCODE
# 11208.0   -0.230904     -0.266636     -0.266257          1.751692   -0.266132
# 11419.0   -0.224987     -0.272644     -0.272283          4.302680   -0.271710
# 11420.0   -0.239403     -0.273053     -0.273029          4.427550   -0.272414
# 11355.0   -0.252718     -0.274414     -0.270759          2.168546   -0.273298
# 11220.0   -0.248998     -0.266587     -0.264027          1.860682   -0.266609
#
#          comp_vio_ratio  POPULATION  disability_r  edu_high_r  edu_low_r  \
# ZIPCODE
# 11208.0       -0.265311    5.072157     -0.267208   -0.267205  -0.267187
# 11419.0       -0.271252    3.422106     -0.273439   -0.273431  -0.273417
# 11420.0       -0.272112    3.235870     -0.273912   -0.273906  -0.273894
# 11355.0       -0.273981    4.890993     -0.274859   -0.274849  -0.274846
# 11220.0       -0.265116    5.053705     -0.267103   -0.267097  -0.267095
#
#              ...        male_pop_r  female_pop_r  elder_pop_r   white_r  \
# ZIPCODE      ...
# 11208.0      ...         -0.267186     -0.267182    -0.267213 -0.267198
# 11419.0      ...         -0.273406     -0.273406    -0.273445 -0.273437
# 11420.0      ...         -0.273882     -0.273878    -0.273919 -0.273907
# 11355.0      ...         -0.274834     -0.274831    -0.274863 -0.274855
# 11220.0      ...         -0.267079     -0.267080    -0.267107 -0.267092
#
#           black_r   asian_r  native_r  towork_less30_r  towork_over30_r  \
# ZIPCODE
# 11208.0 -0.267182 -0.267210 -0.267212        -0.267204        -0.267164
# 11419.0 -0.273431 -0.273422 -0.273444        -0.273428        -0.273384
# 11420.0 -0.273899 -0.273901 -0.273918        -0.273899        -0.273861
# 11355.0 -0.274862 -0.274818 -0.274863        -0.274845        -0.274819
# 11220.0 -0.267106 -0.267084 -0.267107        -0.267093        -0.267066
#
#          cluster_label
# ZIPCODE
# 11208.0              1
# 11419.0              3
# 11420.0              3
# 11355.0              1
# 11220.0              1
#
# [5 rows x 35 columns]

# %%
z = zipfile.ZipFile("../data_initial/ZIP_CODE_040114.zip")
z.extractall("../data_initial/")
zips = gpd.read_file('../data_initial/ZIP_CODE_040114.shx')

# %%
zips = zips.iloc[:,(11,12)]

# %%
zips['ZIPCODE'] = zips['ZIPCODE'].astype(float)

# %%
features_stand = features_stand.reset_index()

# %%
zips.dtypes
# Out:
# ZIPCODE     float64
# geometry     object
# dtype: object

# %%
geodf = pd.merge(zips, features_stand, left_on='ZIPCODE', right_on='ZIPCODE', how='right')

# %%
geodf.head()
# Out:
#    ZIPCODE                                           geometry  complaints  \
# 0  11436.0  POLYGON ((1038098.251871482 188138.3800067157,...   -0.218835
# 1  11213.0  POLYGON ((1001613.712964058 186926.4395172149,...   -0.274229
# 2  11212.0  POLYGON ((1011174.275535807 183696.33770971, 1...   -0.255736
# 3  11225.0  POLYGON ((995908.3654508889 183617.6128015518,...   -0.282822
# 4  11218.0  POLYGON ((991997.1134308875 176307.4958601296,...   -0.276180
#
#    unemployment  poor_english  household_income  violations  comp_vio_ratio  \
# 0     -0.227889     -0.228303          5.413634   -0.228435       -0.227310
# 1     -0.282363     -0.282172          2.467693   -0.282624       -0.281924
# 2     -0.267320     -0.267700          1.520155   -0.268093       -0.262276
# 3     -0.288525     -0.288872          3.257460   -0.289607       -0.286459
# 4     -0.284250     -0.282844          3.253699   -0.284370       -0.283022
#
#    POPULATION  disability_r      ...        male_pop_r  female_pop_r  \
# 0    1.417922     -0.228962      ...         -0.228930     -0.228928
# 1    4.665559     -0.283179      ...         -0.283151     -0.283144
# 2    5.049048     -0.268219      ...         -0.268200     -0.268190
# 3    4.174934     -0.289767      ...         -0.289737     -0.289730
# 4    4.272594     -0.284686      ...         -0.284661     -0.284660
#
#    elder_pop_r   white_r   black_r   asian_r  native_r  towork_less30_r  \
# 0    -0.228973 -0.228968 -0.228911 -0.228967 -0.228972        -0.228951
# 1    -0.283187 -0.283171 -0.283133 -0.283186 -0.283187        -0.283165
# 2    -0.268226 -0.268223 -0.268173 -0.268225 -0.268226        -0.268214
# 3    -0.289773 -0.289756 -0.289717 -0.289771 -0.289772        -0.289755
# 4    -0.284692 -0.284656 -0.284686 -0.284681 -0.284691        -0.284675
#
#    towork_over30_r  cluster_label
# 0        -0.228907              0
# 1        -0.283130              1
# 2        -0.268176              1
# 3        -0.289711              2
# 4        -0.284645              2
#
# [5 rows x 37 columns]

# %%
type(geodf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
geodf.crs = {'init' :'epsg:4326'}
geodf = geodf.set_geometry('geometry')

# %%
geodf.plot(column='cluster_label', colormap='seismic', categorical=True, linewidth=.5, figsize=(10,10), legend=True)
# Out:
# /Users/kristikorsberg/devel/venv/lib/python2.7/site-packages/geopandas/plotting.py:225: FutureWarning: 'colormap' is deprecated, please use 'cmap' instead (for consistency with matplotlib)
#   "(for consistency with matplotlib)", FutureWarning)

# %%
features = features.T
features.head()
# Out:
#          complaints  unemployment  poor_english  household_income  violations  \
# ZIPCODE
# 11208.0       642.0          10.2          16.9           35698.0        19.1
# 11419.0       617.0          10.2          14.8           58266.0        22.1
# 11420.0       438.0          11.0          11.3           59660.0        19.1
# 11355.0       355.0           7.2          65.8           39168.0        25.1
# 11220.0       331.0           9.5          56.3           38893.0         9.1
#
#          comp_vio_ratio  POPULATION  disability_r  edu_high_r  edu_low_r  \
# ZIPCODE
# 11208.0       33.617801     94410.0         0.084       0.132      0.456
# 11419.0       27.923077     47054.0         0.076       0.178      0.363
# 11420.0       22.937173     44538.0         0.096       0.176      0.328
# 11355.0       14.147410     82809.0         0.069       0.238      0.280
# 11220.0       36.384615     97257.0         0.080       0.182      0.211
#
#               ...         below_poverty_r  male_pop_r  female_pop_r  \
# ZIPCODE       ...
# 11208.0       ...                   0.304    0.464682      0.535318
# 11419.0       ...                   0.172    0.499716      0.500284
# 11420.0       ...                   0.131    0.474892      0.525108
# 11355.0       ...                   0.215    0.479961      0.520039
# 11220.0       ...                   0.330    0.511840      0.488160
#
#          elder_pop_r   white_r   black_r   asian_r  native_r  towork_less30_r  \
# ZIPCODE
# 11208.0     0.000083  0.266093  0.543214  0.054354  0.003793         0.144436
# 11419.0     0.000187  0.110392  0.184562  0.292094  0.009350         0.219422
# 11420.0     0.000211  0.161118  0.257517  0.232999  0.016568         0.255918
# 11355.0     0.000182  0.138797  0.028494  0.733180  0.006474         0.294329
# 11220.0     0.000088  0.267989  0.023758  0.412118  0.007193         0.260417
#
#          towork_over30_r
# ZIPCODE
# 11208.0         0.855564
# 11419.0         0.780578
# 11420.0         0.744082
# 11355.0         0.705671
# 11220.0         0.739583
#
# [5 rows x 34 columns]

# %%
features = features.reset_index()

# %%
features.head()
# Out:
#    ZIPCODE  complaints  unemployment  poor_english  household_income  \
# 0  11208.0       642.0          10.2          16.9           35698.0
# 1  11419.0       617.0          10.2          14.8           58266.0
# 2  11420.0       438.0          11.0          11.3           59660.0
# 3  11355.0       355.0           7.2          65.8           39168.0
# 4  11220.0       331.0           9.5          56.3           38893.0
#
#    violations  comp_vio_ratio  POPULATION  disability_r  edu_high_r  \
# 0        19.1       33.617801     94410.0         0.084       0.132
# 1        22.1       27.923077     47054.0         0.076       0.178
# 2        19.1       22.937173     44538.0         0.096       0.176
# 3        25.1       14.147410     82809.0         0.069       0.238
# 4         9.1       36.384615     97257.0         0.080       0.182
#
#         ...         below_poverty_r  male_pop_r  female_pop_r  elder_pop_r  \
# 0       ...                   0.304    0.464682      0.535318     0.000083
# 1       ...                   0.172    0.499716      0.500284     0.000187
# 2       ...                   0.131    0.474892      0.525108     0.000211
# 3       ...                   0.215    0.479961      0.520039     0.000182
# 4       ...                   0.330    0.511840      0.488160     0.000088
#
#     white_r   black_r   asian_r  native_r  towork_less30_r  towork_over30_r
# 0  0.266093  0.543214  0.054354  0.003793         0.144436         0.855564
# 1  0.110392  0.184562  0.292094  0.009350         0.219422         0.780578
# 2  0.161118  0.257517  0.232999  0.016568         0.255918         0.744082
# 3  0.138797  0.028494  0.733180  0.006474         0.294329         0.705671
# 4  0.267989  0.023758  0.412118  0.007193         0.260417         0.739583
#
# [5 rows x 35 columns]

# %%
features['cluster_label'] = labels

# %%
geodf2 = pd.merge(zips, features, on='ZIPCODE', how='right')

# %%
print(len(features_stand))
print(len(features))
print(len(geodf))
print(len(geodf2))
# Out:
# 173
# 173
# 185
# 185

# %%
print(len(labels))
# Out:
# 173

# %%
geodf2[geodf2['cluster_label'] == 3].mean()
# Out:
# ZIPCODE               10912.706897
# complaints              104.327586
# unemployment              8.600000
# poor_english             18.312069
# household_income      68586.206897
# violations                4.927586
# comp_vio_ratio           94.019676
# POPULATION            38621.586207
# disability_r              0.097207
# edu_high_r                0.411034
# edu_low_r                 0.229966
# employment_r              0.596241
# hh                    15632.206897
# hh_with6_r                0.001848
# utility_gas_r             0.663155
# tank_gas_r                0.018431
# electricity_r             0.099638
# fueloil_r                 0.192983
# coal_r                    0.000534
# other_fuels_r             0.012621
# occupied_hu_own_r         0.406279
# occupied_hu_rent_r        0.593721
# built_before1980_r        0.840103
# married_r                 0.416017
# non_eng_r                 0.428655
# below_poverty_r           0.152724
# male_pop_r                0.482672
# female_pop_r              0.517328
# elder_pop_r               0.000367
# white_r                   0.516591
# black_r                   0.184871
# asian_r                   0.146225
# native_r                  0.004961
# towork_less30_r           0.326026
# towork_over30_r           0.673974
# cluster_label             3.000000
# dtype: float64

# %%
geodf2[geodf2['cluster_label'] == 2].mean()
# Out:
# ZIPCODE               10768.969697
# complaints               91.969697
# unemployment             10.221212
# poor_english             22.975758
# household_income      51188.818182
# violations                4.251515
# comp_vio_ratio          132.482368
# POPULATION            57993.212121
# disability_r              0.109273
# edu_high_r                0.351182
# edu_low_r                 0.228424
# employment_r              0.570152
# hh                    22740.000000
# hh_with6_r                0.001144
# utility_gas_r             0.561970
# tank_gas_r                0.017667
# electricity_r             0.083879
# fueloil_r                 0.304091
# coal_r                    0.001758
# other_fuels_r             0.015697
# occupied_hu_own_r         0.279625
# occupied_hu_rent_r        0.720375
# built_before1980_r        0.876000
# married_r                 0.363939
# non_eng_r                 0.496030
# below_poverty_r           0.210515
# male_pop_r                0.474863
# female_pop_r              0.525137
# elder_pop_r               0.000229
# white_r                   0.398955
# black_r                   0.282801
# asian_r                   0.110233
# native_r                  0.004940
# towork_less30_r           0.292571
# towork_over30_r           0.707429
# cluster_label             2.000000
# dtype: float64

# %%
geodf2[geodf2['cluster_label'] == 1].mean()
# Out:
# ZIPCODE               10870.860465
# complaints              158.372093
# unemployment             11.888372
# poor_english             30.727907
# household_income      36499.279070
# violations                8.588372
# comp_vio_ratio           49.774435
# POPULATION            77262.604651
# disability_r              0.119884
# edu_high_r                0.210093
# edu_low_r                 0.286256
# employment_r              0.525953
# hh                    26825.069767
# hh_with6_r                0.000761
# utility_gas_r             0.595140
# tank_gas_r                0.014907
# electricity_r             0.073349
# fueloil_r                 0.290860
# coal_r                    0.000372
# other_fuels_r             0.010651
# occupied_hu_own_r         0.206054
# occupied_hu_rent_r        0.793946
# built_before1980_r        0.863791
# married_r                 0.354628
# non_eng_r                 0.592884
# below_poverty_r           0.293116
# male_pop_r                0.472369
# female_pop_r              0.527631
# elder_pop_r               0.000158
# white_r                   0.296609
# black_r                   0.316239
# asian_r                   0.120951
# native_r                  0.005323
# towork_less30_r           0.265280
# towork_over30_r           0.734720
# cluster_label             1.000000
# dtype: float64

# %%
geodf2[geodf2['cluster_label'] == 0].mean()
# Out:
# ZIPCODE               10726.372549
# complaints               34.725490
# unemployment              7.047059
# poor_english             10.819608
# household_income      86316.862745
# violations                1.492157
# comp_vio_ratio          113.215817
# POPULATION            16689.000000
# disability_r              0.094549
# edu_high_r                0.506333
# edu_low_r                 0.203431
# employment_r              0.630157
# hh                     7601.705882
# hh_with6_r                0.005647
# utility_gas_r             0.574059
# tank_gas_r                0.016314
# electricity_r             0.174157
# fueloil_r                 0.202667
# coal_r                    0.000490
# other_fuels_r             0.015608
# occupied_hu_own_r         0.519396
# occupied_hu_rent_r        0.480604
# built_before1980_r        0.811255
# married_r                 0.432137
# non_eng_r                 0.319412
# below_poverty_r           0.101392
# male_pop_r                0.478160
# female_pop_r              0.521840
# elder_pop_r               0.001093
# white_r                   0.619512
# black_r                   0.134611
# asian_r                   0.163599
# native_r                  0.003517
# towork_less30_r           0.440926
# towork_over30_r           0.559074
# cluster_label             0.000000
# dtype: float64

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
import scipy.stats as stats
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
# Out:
# /Users/kristikorsberg/devel/venv/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#run regression on each cluster

# %%
dfs = []
for i in range(0,4):
    k = geodf2[geodf2['cluster_label'] == i]
    k = k.drop(['geometry', 'cluster_label'], axis=1)
    dfs.append(k)

# %%
cols = dfs[1].columns.tolist()
cols.insert(0,cols.pop(cols.index('ZIPCODE')))
print(cols)
# Out:
# [u'ZIPCODE', 'complaints', 'unemployment', 'poor_english', 'household_income', 'violations', 'comp_vio_ratio', 'POPULATION', 'disability_r', 'edu_high_r', 'edu_low_r', 'employment_r', 'hh', 'hh_with6_r', 'utility_gas_r', 'tank_gas_r', 'electricity_r', 'fueloil_r', 'coal_r', 'other_fuels_r', 'occupied_hu_own_r', 'occupied_hu_rent_r', 'built_before1980_r', 'married_r', 'non_eng_r', 'below_poverty_r', 'male_pop_r', 'female_pop_r', 'elder_pop_r', 'white_r', 'black_r', 'asian_r', 'native_r', 'towork_less30_r', 'towork_over30_r']

# %%
e = []
for elem in cols[2:]:
    e.append(' + ' + elem)
e = ''.join(e)

# %%
#def regress(data):
    #results = smf.ols('complaints ~ ' + e, data=data).fit()
    #print(results.summary())
    #for i, elem in enumerate(cols[2:]):
        #results = smf.ols('complaints ~ ' + elem, data=data).fit()
        #if results.pvalues[1] < .05:
            #plt.figure(figsize=(10,10))
            #plt.plot(data[elem], data['complaints'], 'r.')
            #plt.plot(data[elem], results.predict(sm.add_constant(data[elem])), '-')
            #plt.title('figure ' + str(i) + ':\nillegal residential conversion DOB complaints in 2015 as a function of 2015 ' + elem + '\nNYC Zip Code Level', fontsize=16)
            #plt.xlabel(elem, fontsize=14)
            #plt.ylabel('volume of DOB illegal residential conversion complaints', fontsize=14)

# %%
for elem in dfs:
    print(len(elem))
# Out:
# 51
# 43
# 33
# 58

# %%
for i in range(0,4):
    results = smf.ols('complaints ~ violations + edu_low_r + white_r + black_r + POPULATION', data=dfs[i]).fit()
    print('Results for Cluster ' + str(i))
    print(results.summary())
    print('\n')
# Out:
# Results for Cluster 0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.788
# Model:                            OLS   Adj. R-squared:                  0.764
# Method:                 Least Squares   F-statistic:                     33.45
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           4.32e-14
# Time:                        14:16:16   Log-Likelihood:                -221.21
# No. Observations:                  51   AIC:                             454.4
# Df Residuals:                      45   BIC:                             466.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -8.2285     19.017     -0.433      0.667     -46.530      30.073
# violations    10.5234      1.743      6.038      0.000       7.013      14.033
# edu_low_r     81.1411     27.409      2.960      0.005      25.937     136.345
# white_r       -8.2533     25.846     -0.319      0.751     -60.311      43.804
# black_r       -7.2013     23.095     -0.312      0.757     -53.717      39.314
# POPULATION     0.0010      0.000      3.183      0.003       0.000       0.002
# ==============================================================================
# Omnibus:                       51.087   Durbin-Watson:                   2.226
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              351.413
# Skew:                           2.409   Prob(JB):                     4.92e-77
# Kurtosis:                      14.923   Cond. No.                     2.54e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.54e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Results for Cluster 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.599
# Model:                            OLS   Adj. R-squared:                  0.545
# Method:                 Least Squares   F-statistic:                     11.07
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           1.45e-06
# Time:                        14:16:16   Log-Likelihood:                -244.28
# No. Observations:                  43   AIC:                             500.6
# Df Residuals:                      37   BIC:                             511.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -360.8938     88.390     -4.083      0.000    -539.988    -181.799
# violations     3.0513      1.932      1.580      0.123      -0.863       6.965
# edu_low_r   1287.6657    354.440      3.633      0.001     569.502    2005.829
# white_r      -41.4524     81.877     -0.506      0.616    -207.351     124.446
# black_r      -73.5059     82.797     -0.888      0.380    -241.269      94.257
# POPULATION     0.0021      0.001      2.446      0.019       0.000       0.004
# ==============================================================================
# Omnibus:                       11.109   Durbin-Watson:                   1.766
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.453
# Skew:                           0.948   Prob(JB):                      0.00326
# Kurtosis:                       4.673   Cond. No.                     2.48e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.48e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Results for Cluster 2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.638
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                     9.497
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           2.58e-05
# Time:                        14:16:16   Log-Likelihood:                -168.45
# No. Observations:                  33   AIC:                             348.9
# Df Residuals:                      27   BIC:                             357.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -70.0565     53.185     -1.317      0.199    -179.184      39.071
# violations     6.5090      2.058      3.163      0.004       2.286      10.732
# edu_low_r    360.7144    184.872      1.951      0.061     -18.611     740.040
# white_r      -62.7800     76.585     -0.820      0.420    -219.920      94.360
# black_r      -36.6937     54.420     -0.674      0.506    -148.355      74.967
# POPULATION     0.0015      0.001      2.251      0.033       0.000       0.003
# ==============================================================================
# Omnibus:                        0.488   Durbin-Watson:                   1.559
# Prob(Omnibus):                  0.784   Jarque-Bera (JB):                0.614
# Skew:                           0.228   Prob(JB):                        0.736
# Kurtosis:                       2.512   Cond. No.                     1.48e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.48e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Results for Cluster 3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.797
# Model:                            OLS   Adj. R-squared:                  0.777
# Method:                 Least Squares   F-statistic:                     40.72
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           8.07e-17
# Time:                        14:16:16   Log-Likelihood:                -305.94
# No. Observations:                  58   AIC:                             623.9
# Df Residuals:                      52   BIC:                             636.2
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -4.7698     49.738     -0.096      0.924    -104.576      95.036
# violations     9.9150      1.602      6.187      0.000       6.699      13.131
# edu_low_r    276.5656     98.801      2.799      0.007      78.307     474.824
# white_r     -177.4281     53.070     -3.343      0.002    -283.921     -70.935
# black_r     -142.9423     45.343     -3.152      0.003    -233.930     -51.954
# POPULATION     0.0030      0.001      3.728      0.000       0.001       0.005
# ==============================================================================
# Omnibus:                       26.361   Durbin-Watson:                   1.780
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.947
# Skew:                           1.230   Prob(JB):                     1.44e-16
# Kurtosis:                       7.912   Cond. No.                     6.53e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.53e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
