# %%
import pandas as pd
import matplotlib.pylab as plt
# %pylab inline
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
import scipy.stats as stats
import matplotlib.mlab as mlab
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
# /Users/kristikorsberg/devel/venv/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
features1 = pd.read_csv('../data_processed/acs_merged_features')
features2 = pd.read_csv('../data_processed/acs_zip.csv')
complaints = pd.read_csv('../data_processed/DOB_count_illegal_conv_2015_ZC')

# %%
features1.head()
# Out:
#    Unnamed: 0  Zip Code Unemployment Rate for Pop > 16 Years (%)  \
# 0           0    6390.0                                      9.8
# 1           1   10001.0                                      8.4
# 2           2   10002.0                                      8.9
# 3           3   10003.0                                      6.1
# 4           4   10004.0                                      6.1
#
#   Percentage of Pop > 5 Years Who Don't Speak English at Home and Speak English < 'Very Well'  \
# 0                                                0.0
# 1                                               11.0
# 2                                               37.4
# 3                                                4.9
# 4                                                2.6
#
#   2015 Median Household Income  \
# 0                       151083
# 1                        86801
# 2                        33726
# 3                        98151
# 4                       119691
#
#    Count of Illegal Resident Conversion Violations  comp_vio_ratio
# 0                                              NaN             NaN
# 1                                              0.1      381.000000
# 2                                              2.1       34.809524
# 3                                              3.1       18.096774
# 4                                              0.1       11.000000

# %%
features2.head()
# Out:
#    Unnamed: 0  POPULATION  ZIPCODE    Id2  disability_r  edu_high_r  \
# 0           0     18681.0    11436  11436         0.123       0.177
# 1           1     62426.0    11213  11213         0.106       0.219
# 2           2     83866.0    11212  11212         0.120       0.125
# 3           3     56527.0    11225  11225         0.069       0.315
# 4           4     72280.0    11218  11218         0.086       0.418
#
#    edu_low_r  employment_r       hh  hh_with6_r       ...             pop  \
# 0      0.357         0.578   5454.0    0.002915       ...         19425.0
# 1      0.310         0.532  24163.0    0.000857       ...         64603.0
# 2      0.366         0.461  31443.0    0.000681       ...         88668.0
# 3      0.252         0.575  23133.0    0.000990       ...         60180.0
# 4      0.212         0.607  24909.0    0.001104       ...         75691.0
#
#    male_pop_r  female_pop_r  elder_pop_r   white_r   black_r   asian_r  \
# 0    0.489936      0.510064     0.000587  0.062445  0.701982  0.069086
# 1    0.454638      0.545362     0.000170  0.199464  0.683467  0.017058
# 2    0.422362      0.577638     0.000130  0.049409  0.836040  0.012823
# 3    0.455500      0.544500     0.000189  0.208109  0.701113  0.023845
# 4    0.492502      0.507498     0.000137  0.572750  0.085255  0.171077
#
#    native_r  towork_less30_r  towork_over30_r
# 0  0.008134         0.252197         0.747803
# 1  0.003282         0.278333         0.721667
# 2  0.003259         0.201659         0.798341
# 3  0.004503         0.220052         0.779948
# 4  0.003739         0.266002         0.733998
#
# [5 rows x 32 columns]

# %%
#illegal conversion complaints from 2015
complaints.head()
# Out:
#    Unnamed: 0  Incident Zip  Count of Complaints
# 0          92         11208                  642
# 1         156         11419                  617
# 2         157         11420                  438
# 3         125         11355                  355
# 4         104         11220                  331

# %%
print(len(complaints))
print(len(features1))
print(len(features2))
# Out:
# 176
# 1795
# 248

# %%
#print(complaints.dtypes)
#print(features1.dtypes)
#print(features2.dtypes)

# %%
complaints['Incident Zip'] = complaints['Incident Zip'].astype(float)
features2['ZIPCODE'] = features2['ZIPCODE'].astype(float)

# %%
model = pd.merge(complaints, features1, left_on='Incident Zip', right_on='Zip Code', how='left')

# %%
print(len(model))
# Out:
# 176

# %%
model = pd.merge(model, features2, left_on='Incident Zip', right_on='ZIPCODE', how='outer')

# %%
print(len(model))
# Out:
# 248

# %%
#model.isnull().sum()

# %%
model = model.drop(['Unnamed: 0_x', 'Unnamed: 0_y', 'Zip Code', 'Unnamed: 0', 'Incident Zip', 'Id2'], axis=1)

# %%
model.head()
# Out:
#    Count of Complaints Unemployment Rate for Pop > 16 Years (%)  \
# 0                642.0                                     10.2
# 1                617.0                                     10.2
# 2                438.0                                     11.0
# 3                355.0                                      7.2
# 4                331.0                                      9.5
#
#   Percentage of Pop > 5 Years Who Don't Speak English at Home and Speak English < 'Very Well'  \
# 0                                               16.9
# 1                                               14.8
# 2                                               11.3
# 3                                               65.8
# 4                                               56.3
#
#   2015 Median Household Income  \
# 0                        35698
# 1                        58266
# 2                        59660
# 3                        39168
# 4                        38893
#
#    Count of Illegal Resident Conversion Violations  comp_vio_ratio  \
# 0                                             19.1       33.617801
# 1                                             22.1       27.923077
# 2                                             19.1       22.937173
# 3                                             25.1       14.147410
# 4                                              9.1       36.384615
#
#    POPULATION  ZIPCODE  disability_r  edu_high_r       ...              pop  \
# 0     94410.0  11208.0         0.084       0.132       ...          93847.0
# 1     47054.0  11419.0         0.076       0.178       ...          49306.0
# 2     44538.0  11420.0         0.096       0.176       ...          50820.0
# 3     82809.0  11355.0         0.069       0.238       ...          82790.0
# 4     97257.0  11220.0         0.080       0.182       ...         102325.0
#
#    male_pop_r  female_pop_r  elder_pop_r   white_r   black_r   asian_r  \
# 0    0.464682      0.535318     0.000083  0.266093  0.543214  0.054354
# 1    0.499716      0.500284     0.000187  0.110392  0.184562  0.292094
# 2    0.474892      0.525108     0.000211  0.161118  0.257517  0.232999
# 3    0.479961      0.520039     0.000182  0.138797  0.028494  0.733180
# 4    0.511840      0.488160     0.000088  0.267989  0.023758  0.412118
#
#    native_r  towork_less30_r  towork_over30_r
# 0  0.003793         0.144436         0.855564
# 1  0.009350         0.219422         0.780578
# 2  0.016568         0.255918         0.744082
# 3  0.006474         0.294329         0.705671
# 4  0.007193         0.260417         0.739583
#
# [5 rows x 36 columns]

# %%
model = model.rename(columns={'Count of Complaints':'complaints', 'Unemployment Rate for Pop > 16 Years (%)':'unemployment',"Percentage of Pop > 5 Years Who Don't Speak English at Home and Speak English < 'Very Well'":'poor_english','2015 Median Household Income':'household_income', 'Count of Illegal Resident Conversion Violations':'violations'})

# %%
model.head()
# Out:
#    complaints unemployment poor_english household_income  violations  \
# 0       642.0         10.2         16.9            35698        19.1
# 1       617.0         10.2         14.8            58266        22.1
# 2       438.0         11.0         11.3            59660        19.1
# 3       355.0          7.2         65.8            39168        25.1
# 4       331.0          9.5         56.3            38893         9.1
#
#    comp_vio_ratio  POPULATION  ZIPCODE  disability_r  edu_high_r  \
# 0       33.617801     94410.0  11208.0         0.084       0.132
# 1       27.923077     47054.0  11419.0         0.076       0.178
# 2       22.937173     44538.0  11420.0         0.096       0.176
# 3       14.147410     82809.0  11355.0         0.069       0.238
# 4       36.384615     97257.0  11220.0         0.080       0.182
#
#         ...              pop  male_pop_r  female_pop_r  elder_pop_r   white_r  \
# 0       ...          93847.0    0.464682      0.535318     0.000083  0.266093
# 1       ...          49306.0    0.499716      0.500284     0.000187  0.110392
# 2       ...          50820.0    0.474892      0.525108     0.000211  0.161118
# 3       ...          82790.0    0.479961      0.520039     0.000182  0.138797
# 4       ...         102325.0    0.511840      0.488160     0.000088  0.267989
#
#     black_r   asian_r  native_r  towork_less30_r  towork_over30_r
# 0  0.543214  0.054354  0.003793         0.144436         0.855564
# 1  0.184562  0.292094  0.009350         0.219422         0.780578
# 2  0.257517  0.232999  0.016568         0.255918         0.744082
# 3  0.028494  0.733180  0.006474         0.294329         0.705671
# 4  0.023758  0.412118  0.007193         0.260417         0.739583
#
# [5 rows x 36 columns]

# %%
model = model.drop('pop', axis=1)
model = model.dropna()

# %%
print(len(model))
# Out:
# 174

# %%
#model.dtypes

# %%
model = model.apply(pd.to_numeric, errors='coerce')

# %%
#http://www.statisticssolutions.com/assumptions-of-multiple-linear-regression/
#assumptions of linear regression 
#1) relationship between x and y is linear 
#test with scatter plots
#2) error between observed and predicted (residuals) values must be normally distributed 
#test by plotting residual values on a histogram with a fitted normal curve or by reviewing a Q-Q-Plot
#3) little to no multicollinearity between independent variables
#4) standard mean error (error of the mean) of dependent variable is independent of independent variables

# %%
cols = model.columns.tolist()
cols.insert(0,cols.pop(cols.index('ZIPCODE')))
print(cols)
# Out:
# ['ZIPCODE', 'complaints', 'unemployment', 'poor_english', 'household_income', 'violations', 'comp_vio_ratio', 'POPULATION', 'disability_r', 'edu_high_r', 'edu_low_r', 'employment_r', 'hh', 'hh_with6_r', 'utility_gas_r', 'tank_gas_r', 'electricity_r', 'fueloil_r', 'coal_r', 'other_fuels_r', 'occupied_hu_own_r', 'occupied_hu_rent_r', 'built_before1980_r', 'married_r', 'non_eng_r', 'below_poverty_r', 'male_pop_r', 'female_pop_r', 'elder_pop_r', 'white_r', 'black_r', 'asian_r', 'native_r', 'towork_less30_r', 'towork_over30_r']

# %%
model = model.reindex(columns=cols)

# %% [markdown]
# ### Check the assumptions for a linear model
# Is the relationship between x and y linear?

# %%
for i, elem in enumerate(cols[2:]):
    plt.figure(figsize=(8,8))
    plt.plot(model[elem], model['complaints'], 'r.')
    plt.title('figure ' + str(i) +  ' :\nscatter plot of ' + elem + ' and complaints to check for linearity', fontsize=12)
    plt.xlabel(elem + ' 2015', fontsize=12)
    plt.ylabel('volume of DOB illegal residence conversion complaints', fontsize=12)

# %% [markdown]
# Are the residuals normally distributed for each variable?

# %%
for i, elem in enumerate(cols[2:]):
    results = smf.ols('complaints ~ ' + elem, data=model).fit()
    residuals = sorted(results.resid) # just in case it isn't sorted

    mu = np.mean(residuals) # mean of distribution
    sigma = np.std(residuals) # standard deviation of distribution

    num_bins = 20
    # the histogram of the data
    n, bins, patches = plt.hist(residuals, num_bins, normed=1, facecolor='blue')

    # add a 'normal best fit' line
    y = mlab.normpdf(bins, mu, sigma)
    plt.plot(bins, y, 'r--')
    plt.xlabel('distribution of residuals for ' + elem, fontsize=12)
    plt.ylabel('probability', fontsize=12)
    plt.title('histogram of ' + elem + ' residuals \nfitted normal distribution curve', fontsize=14)

    # tweak spacing to prevent clipping of ylabel
    plt.subplots_adjust(left=0.15)
    plt.show()

# %%
e = []
for elem in cols[2:]:
    e.append(' + ' + elem)
e = ''.join(e)

# %% [markdown]
# Residual distribution for entire model?

# %%
results = smf.ols('complaints ~ ' + e, data=model).fit()
residuals = sorted(results.resid) # just in case it isn't sorted

mu = np.mean(residuals) # mean of distribution
sigma = np.std(residuals) # standard deviation of distribution
 
num_bins = 20
# the histogram of the data
n, bins, patches = plt.hist(residuals, num_bins, normed=1, facecolor='blue')
 
# add a 'normal best fit' line
y = mlab.normpdf(bins, mu, sigma)
plt.plot(bins, y, 'r--')
plt.xlabel('Distribution of Residuals for All Features', fontsize=12)
plt.ylabel('Probability', fontsize=12)
plt.title('Histogram of Multi-Variate Residuals \nFitted Normal Distribution Curve', fontsize=14)
 
# tweak spacing to prevent clipping of ylabel
plt.subplots_adjust(left=0.15)
plt.show()

# %%
#are the variables correlated with one another
#model[f].corr(method='pearson')

# %%
#regress dropping NA
results = smf.ols('complaints ~ ' + e, data=model).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     15.22
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           3.91e-31
# Time:                        13:31:37   Log-Likelihood:                -915.43
# No. Observations:                 173   AIC:                             1893.
# Df Residuals:                     142   BIC:                             1991.
# Df Model:                          30
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept            -73.2483    316.357     -0.232      0.817    -698.627     552.131
# unemployment           1.5120      2.266      0.667      0.506      -2.967       5.991
# poor_english          -1.8979      1.356     -1.399      0.164      -4.579       0.784
# household_income       0.0008      0.001      0.973      0.332      -0.001       0.002
# violations             5.6179      1.062      5.288      0.000       3.518       7.718
# comp_vio_ratio         0.0137      0.029      0.480      0.632      -0.043       0.070
# POPULATION             0.0023      0.001      2.839      0.005       0.001       0.004
# disability_r        -191.6139    240.639     -0.796      0.427    -667.311     284.083
# edu_high_r           113.3515    129.872      0.873      0.384    -143.380     370.084
# edu_low_r            574.0338    206.569      2.779      0.006     165.685     982.382
# employment_r          26.8376    151.914      0.177      0.860    -273.467     327.143
# hh                    -0.0028      0.002     -1.338      0.183      -0.007       0.001
# hh_with6_r         -1113.4104   1908.195     -0.583      0.560   -4885.552    2658.731
# utility_gas_r        100.6163    758.386      0.133      0.895   -1398.570    1599.802
# tank_gas_r           335.6208   1110.699      0.302      0.763   -1860.022    2531.263
# electricity_r         37.4802    788.522      0.048      0.962   -1521.280    1596.240
# fueloil_r            -60.9154    749.027     -0.081      0.935   -1541.601    1419.770
# coal_r              2252.9800   2884.614      0.781      0.436   -3449.356    7955.316
# other_fuels_r        119.7233   1112.520      0.108      0.914   -2079.518    2318.965
# occupied_hu_own_r    -63.2157    169.139     -0.374      0.709    -397.572     271.141
# occupied_hu_rent_r   -10.0326    154.973     -0.065      0.948    -316.385     296.320
# built_before1980_r    94.5654     51.701      1.829      0.069      -7.638     196.769
# married_r            -46.9358    128.230     -0.366      0.715    -300.422     206.551
# non_eng_r            -96.8243     99.312     -0.975      0.331    -293.145      99.497
# below_poverty_r      135.2727    129.604      1.044      0.298    -120.929     391.475
# male_pop_r             0.2152    207.729      0.001      0.999    -410.426     410.856
# female_pop_r         -73.4635    190.898     -0.385      0.701    -450.832     303.905
# elder_pop_r        -7063.1875   1.09e+04     -0.646      0.520   -2.87e+04    1.46e+04
# white_r             -181.3949     73.744     -2.460      0.015    -327.172     -35.618
# black_r             -223.4986     71.627     -3.120      0.002    -365.092     -81.905
# asian_r               71.1154     88.741      0.801      0.424    -104.308     246.539
# native_r            1503.2104   1429.649      1.051      0.295   -1322.936    4329.357
# towork_less30_r      -87.4734    157.646     -0.555      0.580    -399.111     224.164
# towork_over30_r       14.2251    167.011      0.085      0.932    -315.924     344.374
# ==============================================================================
# Omnibus:                       82.288   Durbin-Watson:                   1.283
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              496.609
# Skew:                           1.655   Prob(JB):                    1.45e-108
# Kurtosis:                      10.611   Cond. No.                     9.28e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.36e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
for i, elem in enumerate(cols[2:]):
    results = smf.ols('complaints ~ ' + elem, data=model).fit()
    print(results.summary())
    if results.rsquared > .1:
        plt.figure(figsize=(10,10))
        plt.plot(model[elem], model['complaints'], 'r.')
        plt.plot(model[elem], results.predict(sm.add_constant(model[elem])), '-')
        plt.title('figure ' + str(i) + ':\nillegal residential conversion DOB complaints in 2015 as a function of 2015 ' + elem + '\nNYC Zip Code Level', fontsize=16)
        plt.xlabel(elem, fontsize=14)
        plt.ylabel('volume of DOB illegal residential conversion complaints', fontsize=14)
        if elem == 'unemployment':
            plt.ylim(-10, 660)
        elif elem == 'poor_english':
            plt.xlim(-2,70)
            plt.ylim(-10,660)
        elif elem == 'household_income':
            plt.xlim(15000,130000)
            plt.ylim(-10,660)
        elif elem == 'violations':
            plt.xlim(-1,40)
            plt.ylim(-5,660)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     7.155
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):            0.00820
# Time:                        13:31:37   Log-Likelihood:                -1042.3
# No. Observations:                 174   AIC:                             2089.
# Df Residuals:                     172   BIC:                             2095.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       50.7028     19.706      2.573      0.011      11.806      89.599
# unemployment     5.2965      1.980      2.675      0.008       1.388       9.205
# ==============================================================================
# Omnibus:                      112.367   Durbin-Watson:                   0.109
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              767.247
# Skew:                           2.406   Prob(JB):                    2.48e-167
# Kurtosis:                      12.092   Cond. No.                         26.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     15.41
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           0.000125
# Time:                        13:31:37   Log-Likelihood:                -1038.4
# No. Observations:                 174   AIC:                             2081.
# Df Residuals:                     172   BIC:                             2087.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       56.1544     13.206      4.252      0.000      30.089      82.220
# poor_english     2.1231      0.541      3.925      0.000       1.056       3.191
# ==============================================================================
# Omnibus:                      126.988   Durbin-Watson:                   0.189
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1137.209
# Skew:                           2.700   Prob(JB):                    1.14e-247
# Kurtosis:                      14.301   Cond. No.                         44.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.104
# Model:                            OLS   Adj. R-squared:                  0.099
# Method:                 Least Squares   F-statistic:                     19.81
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           1.54e-05
# Time:                        13:31:37   Log-Likelihood:                -1030.4
# No. Observations:                 173   AIC:                             2065.
# Df Residuals:                     171   BIC:                             2071.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept          177.3512     18.759      9.454      0.000     140.323     214.379
# household_income    -0.0012      0.000     -4.451      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                      110.984   Durbin-Watson:                   0.225
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              795.987
# Skew:                           2.355   Prob(JB):                    1.42e-173
# Kurtosis:                      12.394   Cond. No.                     1.76e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.76e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.543
# Model:                            OLS   Adj. R-squared:                  0.540
# Method:                 Least Squares   F-statistic:                     204.4
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           4.62e-31
# Time:                        13:31:37   Log-Likelihood:                -977.76
# No. Observations:                 174   AIC:                             1960.
# Df Residuals:                     172   BIC:                             1966.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     42.5240      6.466      6.577      0.000      29.762      55.286
# violations    11.6072      0.812     14.296      0.000      10.005      13.210
# ==============================================================================
# Omnibus:                       88.207   Durbin-Watson:                   1.154
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              675.261
# Skew:                           1.696   Prob(JB):                    2.34e-147
# Kurtosis:                      12.035   Cond. No.                         10.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     7.276
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):            0.00768
# Time:                        13:31:37   Log-Likelihood:                -1042.3
# No. Observations:                 174   AIC:                             2089.
# Df Residuals:                     172   BIC:                             2095.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        111.1294      8.523     13.039      0.000      94.307     127.952
# comp_vio_ratio    -0.1217      0.045     -2.697      0.008      -0.211      -0.033
# ==============================================================================
# Omnibus:                      110.120   Durbin-Watson:                   0.108
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              725.405
# Skew:                           2.359   Prob(JB):                    3.02e-158
# Kurtosis:                      11.820   Cond. No.                         218.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.254
# Model:                            OLS   Adj. R-squared:                  0.250
# Method:                 Least Squares   F-statistic:                     58.62
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           1.32e-12
# Time:                        13:31:38   Log-Likelihood:                -1020.4
# No. Observations:                 174   AIC:                             2045.
# Df Residuals:                     172   BIC:                             2051.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.1953     13.476      0.682      0.496     -17.405      35.795
# POPULATION     0.0019      0.000      7.656      0.000       0.001       0.002
# ==============================================================================
# Omnibus:                      127.074   Durbin-Watson:                   0.424
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1186.617
# Skew:                           2.680   Prob(JB):                    2.13e-258
# Kurtosis:                      14.616   Cond. No.                     1.10e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.485
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):              0.225
# Time:                        13:31:38   Log-Likelihood:                -1045.1
# No. Observations:                 174   AIC:                             2094.
# Df Residuals:                     172   BIC:                             2101.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      126.7008     23.479      5.396      0.000      80.357     173.045
# disability_r  -264.3395    216.928     -1.219      0.225    -692.524     163.845
# ==============================================================================
# Omnibus:                      105.930   Durbin-Watson:                   0.042
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              647.671
# Skew:                           2.277   Prob(JB):                    2.29e-141
# Kurtosis:                      11.282   Cond. No.                         29.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.240
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     54.19
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           7.20e-12
# Time:                        13:31:38   Log-Likelihood:                -1022.1
# No. Observations:                 174   AIC:                             2048.
# Df Residuals:                     172   BIC:                             2054.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    187.5961     13.638     13.755      0.000     160.676     214.516
# edu_high_r  -233.5549     31.728     -7.361      0.000    -296.181    -170.929
# ==============================================================================
# Omnibus:                      110.543   Durbin-Watson:                   0.442
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              867.186
# Skew:                           2.283   Prob(JB):                    4.93e-189
# Kurtosis:                      12.938   Cond. No.                         5.55
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.297
# Model:                            OLS   Adj. R-squared:                  0.293
# Method:                 Least Squares   F-statistic:                     72.72
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           7.44e-15
# Time:                        13:31:38   Log-Likelihood:                -1015.2
# No. Observations:                 174   AIC:                             2034.
# Df Residuals:                     172   BIC:                             2041.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -42.6976     17.838     -2.394      0.018     -77.908      -7.487
# edu_low_r    602.1056     70.609      8.527      0.000     462.735     741.477
# ==============================================================================
# Omnibus:                       94.790   Durbin-Watson:                   0.522
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              537.272
# Skew:                           2.003   Prob(JB):                    2.15e-117
# Kurtosis:                      10.619   Cond. No.                         11.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     9.342
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):            0.00260
# Time:                        13:31:38   Log-Likelihood:                -1041.3
# No. Observations:                 174   AIC:                             2087.
# Df Residuals:                     172   BIC:                             2093.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      268.4635     55.737      4.817      0.000     158.447     378.480
# employment_r  -289.4497     94.702     -3.056      0.003    -476.377    -102.522
# ==============================================================================
# Omnibus:                      110.016   Durbin-Watson:                   0.126
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              738.075
# Skew:                           2.347   Prob(JB):                    5.36e-161
# Kurtosis:                      11.932   Cond. No.                         17.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     17.25
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           5.14e-05
# Time:                        13:31:38   Log-Likelihood:                -1037.6
# No. Observations:                 174   AIC:                             2079.
# Df Residuals:                     172   BIC:                             2085.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     42.2005     15.567      2.711      0.007      11.474      72.927
# hh             0.0032      0.001      4.154      0.000       0.002       0.005
# ==============================================================================
# Omnibus:                      117.068   Durbin-Watson:                   0.186
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              888.406
# Skew:                           2.489   Prob(JB):                    1.22e-193
# Kurtosis:                      12.887   Cond. No.                     4.38e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.38e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     12.04
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           0.000657
# Time:                        13:31:38   Log-Likelihood:                -1040.0
# No. Observations:                 174   AIC:                             2084.
# Df Residuals:                     172   BIC:                             2090.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    115.5335      8.604     13.428      0.000      98.550     132.517
# hh_with6_r -7093.0343   2043.813     -3.470      0.001   -1.11e+04   -3058.849
# ==============================================================================
# Omnibus:                      114.845   Durbin-Watson:                   0.144
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              799.779
# Skew:                           2.469   Prob(JB):                    2.14e-174
# Kurtosis:                      12.270   Cond. No.                         281.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.220
# Model:                            OLS   Adj. R-squared:                  0.215
# Method:                 Least Squares   F-statistic:                     48.47
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           6.77e-11
# Time:                        13:31:38   Log-Likelihood:                -1024.3
# No. Observations:                 174   AIC:                             2053.
# Df Residuals:                     172   BIC:                             2059.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       -39.5153     21.055     -1.877      0.062     -81.076       2.045
# utility_gas_r   227.1322     32.623      6.962      0.000     162.740     291.525
# ==============================================================================
# Omnibus:                      108.046   Durbin-Watson:                   0.479
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              777.761
# Skew:                           2.254   Prob(JB):                    1.29e-169
# Kurtosis:                      12.325   Cond. No.                         6.81
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.5596
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):              0.455
# Time:                        13:31:38   Log-Likelihood:                -1045.6
# No. Observations:                 174   AIC:                             2095.
# Df Residuals:                     172   BIC:                             2102.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     86.3050     19.278      4.477      0.000      48.252     124.358
# tank_gas_r   804.3617   1075.276      0.748      0.455   -1318.075    2926.798
# ==============================================================================
# Omnibus:                      110.276   Durbin-Watson:                   0.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              716.736
# Skew:                           2.371   Prob(JB):                    2.31e-156
# Kurtosis:                      11.739   Cond. No.                         143.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.146
# Method:                 Least Squares   F-statistic:                     30.62
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           1.15e-07
# Time:                        13:31:38   Log-Likelihood:                -1031.6
# No. Observations:                 174   AIC:                             2067.
# Df Residuals:                     172   BIC:                             2074.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       135.1022      9.447     14.301      0.000     116.455     153.750
# electricity_r  -334.2048     60.391     -5.534      0.000    -453.409    -215.001
# ==============================================================================
# Omnibus:                      118.719   Durbin-Watson:                   0.295
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              951.066
# Skew:                           2.509   Prob(JB):                    3.01e-207
# Kurtosis:                      13.295   Cond. No.                         8.81
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     13.19
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           0.000371
# Time:                        13:31:38   Log-Likelihood:                -1039.5
# No. Observations:                 174   AIC:                             2083.
# Df Residuals:                     172   BIC:                             2089.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    139.1440     13.084     10.635      0.000     113.318     164.970
# fueloil_r   -167.1294     46.012     -3.632      0.000    -257.950     -76.308
# ==============================================================================
# Omnibus:                      101.589   Durbin-Watson:                   0.178
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              607.314
# Skew:                           2.165   Prob(JB):                    1.33e-132
# Kurtosis:                      11.063   Cond. No.                         6.71
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.7703
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):              0.381
# Time:                        13:31:38   Log-Likelihood:                -1045.5
# No. Observations:                 174   AIC:                             2095.
# Df Residuals:                     172   BIC:                             2101.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    102.2656      8.105     12.618      0.000      86.268     118.264
# coal_r     -3950.9571   4501.793     -0.878      0.381   -1.28e+04    4934.916
# ==============================================================================
# Omnibus:                      108.651   Durbin-Watson:                   0.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              683.870
# Skew:                           2.341   Prob(JB):                    3.16e-149
# Kurtosis:                      11.509   Cond. No.                         600.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.126
# Method:                 Least Squares   F-statistic:                     25.85
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           9.55e-07
# Time:                        13:31:38   Log-Likelihood:                -1033.7
# No. Observations:                 174   AIC:                             2071.
# Df Residuals:                     172   BIC:                             2078.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       136.4760     10.093     13.522      0.000     116.555     156.397
# other_fuels_r -2732.5791    537.412     -5.085      0.000   -3793.350   -1671.808
# ==============================================================================
# Omnibus:                      110.862   Durbin-Watson:                   0.278
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              782.323
# Skew:                           2.345   Prob(JB):                    1.32e-170
# Kurtosis:                      12.269   Cond. No.                         76.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.135
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):              0.288
# Time:                        13:31:38   Log-Likelihood:                -1045.3
# No. Observations:                 174   AIC:                             2095.
# Df Residuals:                     172   BIC:                             2101.
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            86.5616     14.344      6.035      0.000      58.249     114.875
# occupied_hu_own_r    35.5229     33.347      1.065      0.288     -30.300     101.346
# ==============================================================================
# Omnibus:                      109.177   Durbin-Watson:                   0.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              699.419
# Skew:                           2.347   Prob(JB):                    1.33e-152
# Kurtosis:                      11.628   Cond. No.                         5.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.135
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):              0.288
# Time:                        13:31:38   Log-Likelihood:                -1045.3
# No. Observations:                 174   AIC:                             2095.
# Df Residuals:                     172   BIC:                             2101.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept            122.0845     22.413      5.447      0.000      77.845     166.324
# occupied_hu_rent_r   -35.5229     33.347     -1.065      0.288    -101.346      30.300
# ==============================================================================
# Omnibus:                      109.177   Durbin-Watson:                   0.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              699.419
# Skew:                           2.347   Prob(JB):                    1.33e-152
# Kurtosis:                      11.628   Cond. No.                         6.30
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     7.178
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):            0.00810
# Time:                        13:31:38   Log-Likelihood:                -1042.3
# No. Observations:                 174   AIC:                             2089.
# Df Residuals:                     172   BIC:                             2095.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept            -42.2723     53.460     -0.791      0.430    -147.795      63.250
# built_before1980_r   168.2759     62.810      2.679      0.008      44.299     292.253
# ==============================================================================
# Omnibus:                      113.693   Durbin-Watson:                   0.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              802.451
# Skew:                           2.427   Prob(JB):                    5.62e-175
# Kurtosis:                      12.333   Cond. No.                         14.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     3.911
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):             0.0496
# Time:                        13:31:38   Log-Likelihood:                -1043.9
# No. Observations:                 174   AIC:                             2092.
# Df Residuals:                     172   BIC:                             2098.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     44.7053     28.731      1.556      0.122     -12.006     101.416
# married_r    137.7604     69.659      1.978      0.050       0.263     275.258
# ==============================================================================
# Omnibus:                      110.168   Durbin-Watson:                   0.072
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              732.637
# Skew:                           2.356   Prob(JB):                    8.12e-160
# Kurtosis:                      11.880   Cond. No.                         10.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     10.18
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):            0.00169
# Time:                        13:31:38   Log-Likelihood:                -1040.9
# No. Observations:                 174   AIC:                             2086.
# Df Residuals:                     172   BIC:                             2092.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     44.5157     18.747      2.375      0.019       7.512      81.519
# non_eng_r    120.9074     37.900      3.190      0.002      46.099     195.716
# ==============================================================================
# Omnibus:                      119.248   Durbin-Watson:                   0.133
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              911.817
# Skew:                           2.550   Prob(JB):                    1.00e-198
# Kurtosis:                      12.988   Cond. No.                         6.29
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     3.406
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):             0.0667
# Time:                        13:31:38   Log-Likelihood:                -1044.2
# No. Observations:                 174   AIC:                             2092.
# Df Residuals:                     172   BIC:                             2099.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          75.2000     15.171      4.957      0.000      45.256     105.144
# below_poverty_r   133.2996     72.233      1.845      0.067      -9.277     275.876
# ==============================================================================
# Omnibus:                      107.985   Durbin-Watson:                   0.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              672.222
# Skew:                           2.327   Prob(JB):                    1.07e-146
# Kurtosis:                      11.429   Cond. No.                         10.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.6538
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):              0.420
# Time:                        13:31:38   Log-Likelihood:                -1045.6
# No. Observations:                 174   AIC:                             2095.
# Df Residuals:                     172   BIC:                             2101.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -10.6003    136.483     -0.078      0.938    -279.997     258.796
# male_pop_r   230.5586    285.149      0.809      0.420    -332.283     793.400
# ==============================================================================
# Omnibus:                      109.160   Durbin-Watson:                   0.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              696.021
# Skew:                           2.349   Prob(JB):                    7.26e-152
# Kurtosis:                      11.599   Cond. No.                         46.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.6538
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):              0.420
# Time:                        13:31:38   Log-Likelihood:                -1045.6
# No. Observations:                 174   AIC:                             2095.
# Df Residuals:                     172   BIC:                             2101.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      219.9584    149.062      1.476      0.142     -74.269     514.186
# female_pop_r  -230.5586    285.149     -0.809      0.420    -793.400     332.283
# ==============================================================================
# Omnibus:                      109.160   Durbin-Watson:                   0.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              696.021
# Skew:                           2.349   Prob(JB):                    7.26e-152
# Kurtosis:                      11.599   Cond. No.                         48.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.092
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     17.40
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           4.80e-05
# Time:                        13:31:38   Log-Likelihood:                -1037.5
# No. Observations:                 174   AIC:                             2079.
# Df Residuals:                     172   BIC:                             2085.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     122.6090      9.049     13.549      0.000     104.747     140.471
# elder_pop_r -5.384e+04   1.29e+04     -4.171      0.000   -7.93e+04   -2.84e+04
# ==============================================================================
# Omnibus:                      113.619   Durbin-Watson:                   0.132
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              792.503
# Skew:                           2.432   Prob(JB):                    8.13e-173
# Kurtosis:                      12.255   Cond. No.                     1.80e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     25.19
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           1.29e-06
# Time:                        13:31:38   Log-Likelihood:                -1034.0
# No. Observations:                 174   AIC:                             2072.
# Df Residuals:                     172   BIC:                             2078.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    161.9228     14.271     11.346      0.000     133.754     190.092
# white_r     -133.6641     26.633     -5.019      0.000    -186.233     -81.095
# ==============================================================================
# Omnibus:                      105.670   Durbin-Watson:                   0.314
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              672.149
# Skew:                           2.249   Prob(JB):                    1.11e-146
# Kurtosis:                      11.513   Cond. No.                         4.66
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     5.697
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):             0.0181
# Time:                        13:31:39   Log-Likelihood:                -1043.1
# No. Observations:                 174   AIC:                             2090.
# Df Residuals:                     172   BIC:                             2096.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     84.1257      9.837      8.552      0.000      64.709     103.542
# black_r       69.2617     29.019      2.387      0.018      11.983     126.540
# ==============================================================================
# Omnibus:                      110.849   Durbin-Watson:                   0.097
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              713.417
# Skew:                           2.393   Prob(JB):                    1.21e-155
# Kurtosis:                      11.689   Cond. No.                         4.13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     7.515
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):            0.00676
# Time:                        13:31:39   Log-Likelihood:                -1042.2
# No. Observations:                 174   AIC:                             2088.
# Df Residuals:                     172   BIC:                             2095.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     78.7662     10.580      7.445      0.000      57.883      99.649
# asian_r      148.4399     54.147      2.741      0.007      41.561     255.319
# ==============================================================================
# Omnibus:                      109.083   Durbin-Watson:                   0.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              740.787
# Skew:                           2.313   Prob(JB):                    1.38e-161
# Kurtosis:                      11.987   Cond. No.                         7.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.107
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):              0.294
# Time:                        13:31:39   Log-Likelihood:                -1045.3
# No. Observations:                 174   AIC:                             2095.
# Df Residuals:                     172   BIC:                             2101.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     89.1441     12.439      7.167      0.000      64.592     113.696
# native_r    2223.2942   2112.676      1.052      0.294   -1946.815    6393.404
# ==============================================================================
# Omnibus:                      105.604   Durbin-Watson:                   0.041
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              640.974
# Skew:                           2.272   Prob(JB):                    6.52e-140
# Kurtosis:                      11.232   Cond. No.                         282.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.195
# Method:                 Least Squares   F-statistic:                     43.02
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           6.11e-10
# Time:                        13:31:39   Log-Likelihood:                -1026.5
# No. Observations:                 174   AIC:                             2057.
# Df Residuals:                     172   BIC:                             2063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         220.2281     19.586     11.244      0.000     181.568     258.888
# towork_less30_r  -361.2904     55.084     -6.559      0.000    -470.018    -252.563
# ==============================================================================
# Omnibus:                      103.192   Durbin-Watson:                   0.420
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              683.692
# Skew:                           2.159   Prob(JB):                    3.45e-149
# Kurtosis:                      11.698   Cond. No.                         9.11
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.195
# Method:                 Least Squares   F-statistic:                     43.02
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           6.11e-10
# Time:                        13:31:39   Log-Likelihood:                -1026.5
# No. Observations:                 174   AIC:                             2057.
# Df Residuals:                     172   BIC:                             2063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        -141.0623     37.302     -3.782      0.000    -214.692     -67.433
# towork_over30_r   361.2904     55.084      6.559      0.000     252.563     470.018
# ==============================================================================
# Omnibus:                      103.192   Durbin-Watson:                   0.420
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              683.692
# Skew:                           2.159   Prob(JB):                    3.45e-149
# Kurtosis:                      11.698   Cond. No.                         11.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model.to_csv('../data_processed/all_features')

# %%
model = model.dropna()

# %% [markdown]
# ### Test the accuracy of the model by splitting the dataset into train and test samples
# Train test split with all explanatory variables

# %%
# Using cross validation
R_IS=[]
R_OS=[]

n=1000
for i in range(n):
    X_train, X_test, y_train, y_test = train_test_split(model.ix[:,2:], model.ix[:,1], test_size=0.33)
    
    res=LinearRegression(fit_intercept=False)
    res.fit(X_train,y_train)
    #sum the errors 
    R_IS.append(1-((np.asarray(res.predict(X_train))-y_train)**2).sum()/((y_train-np.mean(y_train))**2).sum())                                                                     
    R_OS.append(1-((np.asarray(res.predict(X_test))-y_test)**2).sum()/((y_test-np.mean(y_test))**2).sum())
print("IS R-squared for {} times is {}".format(n,np.mean(R_IS)))
print("OS R-squared for {} times is {}".format(n,np.mean(R_OS)))
# Out:
# /Users/kristikorsberg/devel/venv/lib/python2.7/site-packages/scipy/linalg/basic.py:884: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# IS R-squared for 1000 times is 0.794303884957
# OS R-squared for 1000 times is 0.505930299929

# %%
#run train test split and find out of sample r squared

# %%
#conduct feature selection to see if out of sample r squared improves
#take only significant variables and re-run

# %%
results = smf.ols('complaints ~ violations + edu_low_r + white_r + black_r', data=model).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             complaints   R-squared:                       0.600
# Model:                            OLS   Adj. R-squared:                  0.590
# Method:                 Least Squares   F-statistic:                     62.87
# Date:                Tue, 07 Feb 2017   Prob (F-statistic):           2.13e-32
# Time:                        13:40:01   Log-Likelihood:                -960.74
# No. Observations:                 173   AIC:                             1931.
# Df Residuals:                     168   BIC:                             1947.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -11.9942     27.029     -0.444      0.658     -65.355      41.367
# violations     9.6205      0.910     10.572      0.000       7.824      11.417
# edu_low_r    296.2973     66.047      4.486      0.000     165.908     426.686
# white_r       -9.0401     31.109     -0.291      0.772     -70.455      52.375
# black_r       -6.8028     30.275     -0.225      0.822     -66.572      52.966
# ==============================================================================
# Omnibus:                       84.868   Durbin-Watson:                   1.157
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              590.783
# Skew:                           1.661   Prob(JB):                    5.16e-129
# Kurtosis:                      11.422   Cond. No.                         114.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Train test split on significant variables only

# %%
# Using cross validation
R_IS=[]
R_OS=[]

n=1000
for i in range(n):
    X_train, X_test, y_train, y_test = train_test_split(model.ix[:,(5, 10, 30, 31)], model.ix[:,1], test_size=0.33)
    
    res=LinearRegression(fit_intercept=False)
    res.fit(X_train,y_train)
    R_IS.append(1-((np.asarray(res.predict(X_train))-y_train)**2).sum()/((y_train-np.mean(y_train))**2).sum())                                                                     
    R_OS.append(1-((np.asarray(res.predict(X_test))-y_test)**2).sum()/((y_test-np.mean(y_test))**2).sum())
print("IS R-squared for {} times is {}".format(n,np.mean(R_IS)))
print("OS R-squared for {} times is {}".format(n,np.mean(R_OS)))
# Out:
# IS R-squared for 1000 times is 0.609481188855
# OS R-squared for 1000 times is 0.515000697528
